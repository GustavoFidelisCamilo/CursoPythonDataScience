# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\xnosp\desktop\estudos\faculdade\quinto periodo\ia\cursopython\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Data Frame Voos**

# %%
df = pd.read_csv("flights.csv", sep=",")

# %%
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    object
#  2   passengers  144 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 3.5+ KB

# %%
df.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %% [markdown]
# **Inicializando com os plots**

# %%
sns.displot(df['passengers'], bins=50)

# %%
sns.barplot(x='year',y='passengers', data=df)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='year',y='passengers', data=df)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.jointplot(x='year',y='passengers', data=df)

# %%
sns.pairplot(df,hue='month')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sns.heatmap(df.corr(),annot=True)
#
# File ~\Desktop\Estudos\Faculdade\Quinto Periodo\IA\cursoPython\venv\Lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\Desktop\Estudos\Faculdade\Quinto Periodo\IA\cursoPython\venv\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\Desktop\Estudos\Faculdade\Quinto Periodo\IA\cursoPython\venv\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File ~\Desktop\Estudos\Faculdade\Quinto Periodo\IA\cursoPython\venv\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'January'
